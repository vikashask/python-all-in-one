# %% [markdown]
# # 🤖 Machine Learning - Interactive Notebooks
#
# ## 📚 Welcome!
#
# This collection of Jupyter notebooks provides a comprehensive, hands-on learning path for Machine Learning. Each notebook is designed to be interactive - you can run code blocks, experiment, and see results immediately.
#
# ## 🎯 How to Use These Notebooks
#
# 1. **Run cells sequentially** - Each notebook builds on previous cells
# 2. **Experiment** - Modify code and see what happens
# 3. **Complete exercises** - Practice sections at the end of each notebook
# 4. **Take notes** - Add your own markdown cells with observations
#
# ## 📖 Notebook Structure
#
# ### ✅ Completed Notebooks
#
# 1. **[Phase-0-Prerequisites.ipynb](Phase-0-Prerequisites.ipynb)** ✅
#    - Python basics for ML
#    - NumPy arrays and operations
#    - Pandas DataFrames
#    - Matplotlib & Seaborn visualization
#    - **Time: 1-2 weeks**
#
# ### 🚧 Coming Soon (You can create these using the markdown files)
#
# 2. **Phase-1-ML-Concepts.ipynb**
#    - What is Machine Learning?
#    - Types of ML (Supervised, Unsupervised, etc.)
#    - Overfitting vs Underfitting
#    - Basic ML workflow
#
# 3. **Phase-2-Regression.ipynb**
#    - Linear Regression
#    - Multiple Linear Regression
#    - Polynomial Regression
#    - Ridge, Lasso, ElasticNet
#    - Complete house price prediction project
#
# 4. **Phase-2-Classification.ipynb**
#    - Logistic Regression
#    - K-Nearest Neighbors (KNN)
#    - Naive Bayes
#    - Decision Trees & Random Forest
#    - Support Vector Machines (SVM)
#    - Complete customer churn project
#
# 5. **Phase-3-Unsupervised-Learning.ipynb**
#    - K-Means Clustering
#    - Hierarchical Clustering
#    - DBSCAN
#    - PCA (Principal Component Analysis)
#    - t-SNE visualization
#    - Customer segmentation project
#
# 6. **Phase-4-Feature-Engineering.ipynb**
#    - Handling missing data
#    - Dealing with outliers
#    - Encoding categorical variables
#    - Feature scaling
#    - Feature creation
#    - Building ML pipelines
#
# 7. **Phase-5-6-Advanced-ML.ipynb**
#    - Cross-validation
#    - Hyperparameter tuning
#    - Ensemble methods (Bagging, Boosting)
#    - XGBoost & LightGBM
#    - Model stacking
#
# ## 🛠️ Quick Start
#
# ### Install Required Libraries

# %%
# Run this cell to install all required libraries
# Uncomment the line below if you haven't installed these packages

# !pip install numpy pandas matplotlib seaborn scikit-learn jupyter

# %% [markdown]
# ### Verify Installation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version

print("✅ All libraries installed successfully!")
print(f"\nVersions:")
print(f"  NumPy: {np.__version__}")
print(f"  Pandas: {pd.__version__}")
print(f"  Scikit-learn: {sklearn_version}")
print(f"  Matplotlib: {plt.matplotlib.__version__}")
print(f"  Seaborn: {sns.__version__}")
# Out:
# ✅ All libraries installed successfully!
#
# Versions:
#   NumPy: 2.0.2
#   Pandas: 2.3.3
#   Scikit-learn: 1.6.1
#   Matplotlib: 3.9.4
#   Seaborn: 0.13.2

# %% [markdown]
# ## 📊 Progress Tracker
#
# Track your learning progress:
#
# | Phase | Topic | Status | Completion Date |
# |-------|-------|--------|----------------|
# | 0 | Prerequisites | ⬜ | |
# | 1 | ML Concepts | ⬜ | |
# | 2A | Regression | ⬜ | |
# | 2B | Classification | ⬜ | |
# | 3 | Unsupervised Learning | ⬜ | |
# | 4 | Feature Engineering | ⬜ | |
# | 5-6 | Advanced ML | ⬜ | |
#
# **Legend:** ⬜ Not Started | 🔄 In Progress | ✅ Completed

# %% [markdown]
# ## 💡 Learning Tips
#
# 1. **Run Every Code Block** - Don't just read, execute and observe
# 2. **Experiment** - Change parameters and see what happens
# 3. **Take Notes** - Add markdown cells with your insights
# 4. **Practice** - Complete all exercises
# 5. **Build Projects** - Apply concepts to real problems
# 6. **Review Regularly** - Revisit previous notebooks
#
# ## 🚀 Ready to Start?
#
# Begin with **[Phase-0-Prerequisites.ipynb](Phase-0-Prerequisites.ipynb)** to build your foundation!
#
# ## 📚 Additional Resources
#
# - **Markdown Documentation**: Available in the same folder
# - **Datasets**: Use built-in sklearn datasets or download from Kaggle
# - **Practice Platform**: [Kaggle](https://www.kaggle.com)
#
# ---
#
# ## 🎓 Creating Additional Notebooks
#
# To create notebooks for the remaining phases, you can:
#
# 1. **Use the markdown files** as reference
# 2. **Copy code examples** into new notebook cells
# 3. **Add explanations** in markdown cells
# 4. **Test and run** each code block
#
# Or you can ask me to create specific notebooks for phases you need!
#
# ---
#
# **Happy Learning! 🎉**
#
# *Last Updated: January 2026*
