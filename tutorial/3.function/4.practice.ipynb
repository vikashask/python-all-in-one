# %%
number = list(range(1, 11))
number = list(filter(lambda x: x % 2 == 0, number))
number
# Out:
# [2, 4, 6, 8, 10]

# %%
values = [1, 2, 3, 4, 5,-3,-10]
pos = list(filter(lambda x: x%2==0, values))
pos
# Out:
# [2, 4, -10]

# %%
from functools import reduce
values = [1, 2, 3, 4, 5]
sum_all = reduce(lambda x, y: x + y, values)
sum_all
# Out:
# 15

# %%
from functools import reduce
values = [1, 2, 3, 4, 5]
result = reduce(lambda x, y: x if x > y else y, values)
result
# Out:
# 5
